# %% [markdown]
# Loading libraries

# %%
library(repr)
suppressMessages(library(ggplot2))
suppressMessages(library(dplyr))
suppressMessages(library(iMKT))
suppressMessages(library(forcats))
suppressMessages(library(cowplot))
suppressMessages(library(reshape2))
suppressMessages(library(data.table))
source('/home/jmurga/mkt/201902/scripts/src/plotStyle.R')

# %%
options(repr.plot.width=20, repr.plot.height=15)

# %% [markdown]
# ### Ploting each simulated scenario

# %%
source('/home/jmurga/mkt/201902/scripts/src/simulationsPlot.R')
# Out:
# Attaching package: ‘cowplot’
#
# The following object is masked from ‘package:ggplot2’:
#
#     ggsave
#
#
# Attaching package: ‘reshape2’
#
# The following objects are masked from ‘package:data.table’:
#
#     dcast, melt

# %% [markdown]
# #### Alpha baseline

# %%
baseline <- mktOnsimulatedData(scenario='baseline',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/')
ggsave(baseline[['plot']],file='/home/jmurga/mkt/201902/results/simulations/baseline.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 4 rows containing non-finite values (stat_boxplot).”

# %%
baseline$table
# Out:
#       alphaStandard alphaDGRP0.05 alphaDGRP0.1 alphaFWW0.05 alphaFWW0.1
# mean  -0.2781215    -0.1336262    -0.1542417   0.1281082    0.1772054
# sd    0.06016916    0.05258108    0.0532969    0.04014604   0.03788203
# error 0.6019733     0.4574781     0.4780935    0.1957436    0.1466464
#       alphaAsymptotic alphaAsymptotic0.1 trueAlpha  scenario
# mean  0.255068        0.3039261          0.3238518  baseline
# sd    0.03334026      0.05347963         0.01846842 baseline
# error 0.06878382      0.0435607          0          baseline

# %%
baseline[['plot']]
# Out:
# Warning message:
# “Removed 4 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### r0

# %%
r0 <- mktOnsimulatedData(scenario='r0',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/')
ggsave(r0[['plot']],file='/home/jmurga/mkt/201902/results/simulations/r0.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 15 rows containing non-finite values (stat_boxplot).”

# %% [markdown]
# #### r1e-5

# %%
r1 <- mktOnsimulatedData(scenario='r1e-5',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/')
ggsave(r1[['plot']],file='/home/jmurga/mkt/201902/results/simulations/r1e-5.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”

# %% [markdown]
# #### Length 10e6

# %%
length10e6 <- mktOnsimulatedData(scenario = "length10e6", simulationsPath = "/home/jmurga/mkt/201902/rawData/dmel/simulations/")
ggsave(length10e6[['plot']],file='/home/jmurga/mkt/201902/results/simulations/length10e6.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 18 rows containing non-finite values (stat_boxplot).”

# %%
length10e6[["plot"]]
# Out:
# Warning message:
# “Removed 18 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### Length 10e8

# %%
length10e8 <- mktOnsimulatedData(scenario='length10e8',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');length10e8[['plot']]
ggsave(length10e8[['plot']],file='/home/jmurga/mkt/201902/results/simulations/length10e8.png',height = 15,width = 20)
# Out:
# plot without title

# %% [markdown]
# #### Mutation rate 1e-10

# %%
mu1 <- mktOnsimulatedData(scenario='mu1e-10',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(mu1[['plot']],file='/home/jmurga/mkt/201902/results/simulations/mu2.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 20 rows containing non-finite values (stat_boxplot).”

# %%
mu1[['plot']]
# Out:
# Warning message:
# “Removed 20 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### Mutation rate 1e-8

# %%
mu2 <- mktOnsimulatedData(scenario='mu1e-8',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(mu2[['plot']],file='/home/jmurga/mkt/201902/results/simulations/mu1.png',height = 15,width = 20)

# %%
mu2[['plot']]
# Out:
# plot without title

# %% [markdown]
# #### Alpha Rb1e-4

# %%
rb1 <- mktOnsimulatedData(scenario='rb1e-4',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/')
ggsave(rb1[['plot']],file='/home/jmurga/mkt/201902/results/simulations/rb1.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 5 rows containing non-finite values (stat_boxplot).”

# %%
rb1[['plot']]
# Out:
# Warning message:
# “Removed 5 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### Alpha Rb1e-3

# %%
rb2 <- mktOnsimulatedData(scenario='rb1e-3',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(rb2[['plot']],file='/home/jmurga/mkt/201902/results/simulations/rb2.png',height = 15,width = 20)

# %%
rb2[['plot']]
# Out:
# plot without title

# %% [markdown]
# #### Alpha Sb2e-2

# %%
sb1 <- mktOnsimulatedData(scenario='sb2e-1',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(sb1[['plot']],file='/home/jmurga/mkt/201902/results/simulations/sb1.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”

# %%
sb1[['plot']]
# Out:
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### Alpha Sb2-e1

# %%
sb2 <- mktOnsimulatedData(scenario='sb2e-2',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(sb2[['plot']],file='/home/jmurga/mkt/201902/results/simulations/sb2.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”

# %%
sb2[['plot']]
# Out:
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### Alpha Sd (-2)e-3

# %%
sd1 <- mktOnsimulatedData(scenario='sd-2e-1',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(sd1[['plot']],file='/home/jmurga/mkt/201902/results/simulations/sd1.png',height = 15,width = 20)
# Out:
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Could not fit exponential model for the computation of asymptotic alpha.
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”

# %%
sd1[['plot']]
# Out:
# Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”
# plot without title

# %% [markdown]
# #### Alpha Sd (-2)e-1

# %%
sd2 <- mktOnsimulatedData(scenario='sd-2e-3',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(sd2[['plot']],file='/home/jmurga/mkt/201902/results/simulations/sd2.png',height = 15,width = 20)

# %%
sd2[['plot']]

# %% [markdown]
# #### Alpha generation time 2e4

# %%
t2e4 <- mktOnsimulatedData(scenario='t2e4',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(t2e4[['plot']],file='/home/jmurga/mkt/201902/results/simulations/t2e4.png',height = 15,width = 20)

# %%
t2e4[['plot']]

# %% [markdown]
# #### Alpha generation time 2e6

# %%
t2e6 <- mktOnsimulatedData(scenario='t2e6',simulationsPath='/home/jmurga/mkt/201902/rawData/dmel/simulations/');
ggsave(t2e6[['plot']],file='/home/jmurga/mkt/201902/results/simulations/t2e6.svg',height = 15,width = 20)

# %%
t2e6[['plot']]

# %% [markdown]
# ### Extract simulation table

# %%
output <- rbind(baseline$table,r0$table,r1$table,length10e6$table,length10e8$table,mu1$table,mu2$table,rb1$table,rb2$table,sb1$table,sb2$table,sd1$table,sd2$table,t2e4$table,t2e6$table)

output <- output %>% select(scenario, everything())

fwrite(output,file='/home/jmurga/mkt/201902/results/simulations/simulationsMetrics.tab',sep='\t',row.names=T,col.names=T)

# %%
output <- rbind(baseline$table,r0$table,r1$table,length10e6$table,length10e8$table,mu1$table,mu2$table,rb1$table,rb2$table,sb1$table,sb2$table,sd1$table,sd2$table,t2e4$table,t2e6$table)

# %%
r0$table
# Out:
#       alphaStandard alphaDGRP0.05 alphaDGRP0.1 alphaFWW0.05 alphaFWW0.1
# mean  -0.1974116    -0.1298932    -0.1499595   0.1684907    0.2140549
# sd    0.05376889    0.04894312    0.05021393   0.03668418   0.03778398
# error 0.4374562     0.3699378     0.3900041    0.07240174   0.03563165
#       alphaAsymptotic alphaAsymptotic0.1 trueAlpha  scenario
# mean  0.243846        0.2947629          0.2400446  r0
# sd    0.04096374      0.06160027         0.01354769 r0
# error 0.03136984      0.06219929         0          r0

# %%
output
# Out:
#         alphaStandard alphaDGRP0.05 alphaDGRP0.1 alphaFWW0.05 alphaFWW0.1
# mean    -0.2781215    -0.1336262    -0.1542417   0.1281082    0.1772054
# sd      0.06016916    0.05258108    0.0532969    0.04014604   0.03788203
# error   0.6019733     0.4574781     0.4780935    0.1957436    0.1466464
# mean1   -0.1974116    -0.1298932    -0.1499595   0.1684907    0.2140549
# sd1     0.05376889    0.04894312    0.05021393   0.03668418   0.03778398
# error1  0.4374562     0.3699378     0.3900041    0.07240174   0.03563165
# mean2   -0.2890214    -0.1379432    -0.1589763   0.1270101    0.1771953
# sd2     0.06717865    0.05550425    0.05587426   0.03976259   0.0356768
# error2  0.6165623     0.4654841     0.4865172    0.2005308    0.1503456
# mean3   -0.3189023    -0.1626814    -0.1847817   0.1171425    0.1703129
# sd3     0.2397592     0.203015      0.2069826    0.149127     0.1407281
# error3  0.649295      0.4930741     0.5151744    0.217391     0.1690919
# mean4   -0.2778936    -0.1315045    -0.1519919   0.1335294    0.1845155
# sd4     0.01902118    0.01556401    0.01574283   0.01070557   0.009533815
# error4  0.6044579     0.4580688     0.4785561    0.1930349    0.1420488
# mean5   -0.2631424    -0.1155354    -0.1334618   0.1423266    0.1972618
# sd5     0.1672013     0.1344417     0.1345707    0.09511585   0.08658009
# error5  0.6062942     0.4586871     0.4766136    0.2034896    0.1537994
# mean6   -0.2829315    -0.1549241    -0.1761143   0.1287186    0.1788665
# sd6     0.01659458    0.01409487    0.01434779   0.0106955    0.01006733
# error6  0.5889243     0.4609169     0.4821071    0.1772742    0.1271263
# mean7   -0.7358803    -0.5354869    -0.5634021   -0.1795149   -0.1115289
# sd7     0.1014814     0.08672579    0.0882051    0.06490691   0.06149755
# error7  0.8227288     0.6223354     0.6502505    0.2663634    0.1983773
# mean8   0.02486098    0.1340588     0.1181348    0.3356264    0.3730278
# sd8     0.055061      0.04736383    0.04773033   0.03650084   0.03338453
# error8  0.4628222     0.3536243     0.3695484    0.1520568    0.1146553
# mean9   0.008669111   0.1191776     0.1028276    0.3281158    0.3666685
# sd9     0.04815232    0.04156365    0.04225649   0.03220498   0.03045888
# error9  0.4593994     0.3488909     0.3652409    0.1399528    0.1014
# mean10  -0.7343106    -0.5316074    -0.5595111   -0.17343     -0.104432
# sd10    0.09941166    0.08324301    0.08458701   0.05829551   0.05291254
# error10 0.8279904     0.6252873     0.653191     0.2671098    0.1981118
# mean11  -0.2643658    -0.07589513   -0.1078722   0.2645673    0.3089452
# sd11    0.07536343    0.05980154    0.06154863   0.03728861   0.03416065
# error11 0.6973008     0.5088302     0.5408072    0.1683677    0.1239898
# mean12  -0.1176424    -0.05294369   -0.05689655  0.06350709   0.1044906
# sd12    0.05395523    0.04857507    0.04886358   0.04151087   0.04023339
# error12 0.3558472     0.2911485     0.2951014    0.1746977    0.1337142
# mean13  -0.1916414    -0.04968414   -0.06886458  0.2056736    0.2564337
# sd13    0.2196382     0.193119      0.1935038    0.151197     0.1350748
# error13 0.5648098     0.4228525     0.4420329    0.1793846    0.1425856
# mean14  -0.282248     -0.1359272    -0.1566575   0.1285265    0.1786289
# sd14    0.01831038    0.01511563    0.01521924   0.01138007   0.01069803
# error14 0.6041965     0.4578757     0.4786061    0.1934221    0.1433196
#         alphaAsymptotic alphaAsymptotic0.1 trueAlpha   scenario
# mean    0.255068        0.3039261          0.3238518   baseline
# sd      0.03334026      0.05347963         0.01846842  baseline
# error   0.06878382      0.0435607          0           baseline
# mean1   0.243846        0.2947629          0.2400446   r0
# sd1     0.04096374      0.06160027         0.01354769  r0
# error1  0.03136984      0.06219929         0           r0
# mean2   0.25845         0.3133043          0.3275409   r1e-5
# sd2     0.03916377      0.05882749         0.02015037  r1e-5
# error2  0.06932744      0.04620277         0           r1e-5
# mean3   0.251652        0.3170281          0.3303927   length10e6
# sd3     0.1346176       0.1493303          0.06639986  length10e6
# error3  0.1105591       0.1226655          0           length10e6
# mean4   0.25896         0.30259            0.3265643   length10e8
# sd4     0.008349655     0.01426992         0.006315866 length10e8
# error4  0.06760426      0.02398198         0           length10e8
# mean5   0.3047          0.3602324          0.3431518   mu1e-10
# sd5     0.09957483      0.1484728          0.05308438  mu1e-10
# error5  0.08460698      0.1222231          0           mu1e-10
# mean6   0.246732        0.288564           0.3059928   mu1e-8
# sd6     0.01041368      0.01783264         0.005050278 mu1e-8
# error6  0.05926078      0.02084546         0           mu1e-8
# mean7   0.00428         0.06304667         0.08684845  rb1e-4
# sd7     0.0558588       0.07358755         0.0142028   rb1e-4
# error7  0.08367766      0.05698634         0           rb1e-4
# mean8   0.422432        0.469252           0.4876832   rb1e-3
# sd8     0.02883997      0.03746777         0.01781242  rb1e-3
# error8  0.06525118      0.02737902         0           rb1e-3
# mean9   0.41937         0.449583           0.4680685   sb2e-1
# sd9     0.02687014      0.03553829         0.01848648  sb2e-1
# error9  0.04903496      0.03059823         0           sb2e-1
# mean10  0.00761         0.08185319         0.09367985  sb2e-2
# sd10    0.04471849      0.0653791          0.01324197  sb2e-2
# error10 0.0863184       0.0529241          0           sb2e-2
# mean11  0.358574        0.4083957          0.432935    sd-2e-1
# sd11    0.02913988      0.04304927         0.02270722  sd-2e-1
# error11 0.07436102      0.03911472         0           sd-2e-1
# mean12  0.200626        0.2232289          0.2382048   sd-2e-3
# sd12    0.03572206      0.05022306         0.01373586  sd-2e-3
# error12 0.04192736      0.04061109         0           sd-2e-3
# mean13  0.3480417       0.3992379          0.3731683   t2e4
# sd13    0.1540565       0.1712847          0.06518702  t2e4
# error13 0.1071762       0.1316607          0           t2e4
# mean14  0.252806        0.299686           0.3219485   t2e6
# sd14    0.01221467      0.01691809         0.005705945 t2e6
# error14 0.06914252      0.0239518          0           t2e6

# %% [markdown]
# ### Grid all scenarios

# %%
svg('/home/jmurga/mkt/201902/results/simulations/simulationsMKT.svg',height = 30, width = 25)
plot_grid(baseline[['plot']],NULL,NULL,NULL,
          length10e6[['plot']],length10e8[['plot']],
          mu1[['plot']],mu2[['plot']],
          rb1[['plot']],rb2[['plot']],
          sb1[['plot']],sb2[['plot']],
          sd1[['plot']],sd2[['plot']],
          t2e4[['plot']],t2e6[['plot']],
          NULL,r0[['plot']],r1[['plot']],NULL,
          ncol=4,
          labels=c("A","",LETTERS[2:15]))
dev.off()
# Out:
# Warning message:
# “Removed 4 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 18 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 20 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 5 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 3 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 5 rows containing non-finite values (stat_boxplot).”Warning message:
# “Removed 23 rows containing non-finite values (stat_boxplot).”
# png
#   2

# %% [markdown]
# ### Weakly deleterious fraction on SLiM data

# %%
setwd('/home/jmurga/mkt/201902/rawData/dmel/simulations/baseline/')
listDaf <- lapply(list.files(pattern = 'daf',recursive=T),fread)
listDiv <- lapply(list.files(pattern = 'div',recursive=T),fread,sep='\t',header=T)
