# %%
library(iMKT)

# %%
genes <- unique(PopFlyData[['Name']]) %>% as.matrix()

# %%
samplingGenes <- function(geneList,sample,B,bins,seed=213){
    set.seed(213)
    genes <- sample(geneList,size=1000)
    boot.samples.bins_2 = matrix(sample(genes,size = B*bins,replace=T),B,bins)
    
    for (i in 1:B) {
       write(as.character(boot.samples.bins_2[i,]),file = paste0("./sampling_bins_2/bins_2.boot_",i))
    }
    
}






B=3500
n=2
set.seed(213)

boot.samples.bins_2 = matrix(sample(genes,size = B*n,replace = T),B,n)
# Out:
#       .
# 1     FBgn0000008
# 2     FBgn0000014
# 3     FBgn0000015
# 4     FBgn0000017
# 5     FBgn0000018
# 6     FBgn0000022
# 7     FBgn0000024
# 8     FBgn0000028
# 9     FBgn0000032
# 10    FBgn0000036
# 11    FBgn0000037
# 12    FBgn0000038
# 13    FBgn0000039
# 14    FBgn0000042
# 15    FBgn0000043
# 16    FBgn0000044
# 17    FBgn0000045
# 18    FBgn0000046
# 19    FBgn0000047
# 20    FBgn0000052
# 21    FBgn0000053
# 22    FBgn0000054
# 23    FBgn0000055
# 24    FBgn0000056
# 25    FBgn0000057
# 26    FBgn0000061
# 27    FBgn0000063
# 28    FBgn0000064
# 29    FBgn0000071
# 30    FBgn0000075
# ⋮     ⋮
# 13724 FBgn0267002
# 13725 FBgn0267033
# 13726 FBgn0267042
# 13727 FBgn0267043
# 13728 FBgn0267044
# 13729 FBgn0267045
# 13730 FBgn0267046
# 13731 FBgn0267047
# 13732 FBgn0267048
# 13733 FBgn0267049
# 13734 FBgn0267050
# 13735 FBgn0267104
# 13736 FBgn0267105
# 13737 FBgn0267106
# 13738 FBgn0267163
# 13739 FBgn0267236
# 13740 FBgn0267252
# 13741 FBgn0267253
# 13742 FBgn0267254
# ...
